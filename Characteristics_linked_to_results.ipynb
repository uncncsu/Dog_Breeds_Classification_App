# %% [markdown]
# # Dependencies and Setup

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import psycopg2

# %% [markdown]
# # Extract (from csv's)

# %%
#manually edited some naming conventions to ensure matching with csv of list used in ML
# and inserted purchasing information when available and added missing breeds...
#ie. icelandic sheepdog and irish red and white setter; altering some naming conventions
# that matches both images and characteristics of the names used from the training source

csv_file1 = "./Resources/dog_breed_characteristics_copy_droppedrows.csv"
characteristics = pd.read_csv(csv_file1)

# %%
#retain relevant columns (ie drop malayasia and see where gaps are in intelligence)
characteristics_subset = characteristics[["BreedName", "Group1", "Group2", "MaleWtKg", "Temperment", "AvgPupPrice", "Intelligence", "Watchdog", "PopularityUS2017"]]

# %%
#import csv of doglist to cross-check rows in BreedName column
csv_file2 = "./Resources/dogbreedlist_copy.csv"
doglist = pd.read_csv(csv_file2, skiprows=0, names=["BreedName"])

# %%
doglist.count
# Out:
# <bound method DataFrame.count of                               BreedName
# 0                         Affenpinscher
# 1                          Afghan_hound
# 2                      Airedale_terrier
# 3                                 Akita
# 4                      Alaskan_malamute
# 5                   American_eskimo_dog
# 6                     American_foxhound
# 7      American_staffordshire_terrier
# 8                American_water_spaniel
# 9                Anatolian_shepherd_dog
# 10                Australian_cattle_dog
# 11                  Australian_shepherd
# 12                   Australian_terrier
# 13                              Basenji
# 14                         Basset_hound
# 15                               Beagle
# 16                       Bearded_collie
# 17                            Beauceron
# 18                   Bedlington_terrier
# 19                     Belgian_malinois
# 20                     Belgian_sheepdog
# 21                     Belgian_tervuren
# 22                 Bernese_mountain_dog
# 23                         Bichon_frise
# 24              Black_and_tan_coonhound
# 25                Black_russian_terrier
# 26                           Bloodhound
# 27                   Bluetick_coonhound
# 28                        Border_collie
# 29                       Border_terrier
# ..                                  ...
# 103                 Miniature_schnauzer
# 104                  Neapolitan_mastiff
# 105                        Newfoundland
# 106                     Norfolk_terrier
# 107                    Norwegian_buhund
# 108                  Norwegian_elkhound
# 109                 Norwegian_lundehund
# 110                     Norwich_terrier
# 111  Nova_scotia_duck_tolling_retriever
# 112                Old_english_sheepdog
# 113                          Otterhound
# 114                            Papillon
# 115              Parson_russell_terrier
# 116                           Pekingese
# 117                Pembroke_welsh_corgi
# 118        Petit_basset_griffon_vendeen
# 119                       Pharaoh_hound
# 120                               Plott
# 121                             Pointer
# 122                          Pomeranian
# 123                              Poodle
# 124                Portuguese_water_dog
# 125                       Saint_bernard
# 126                       Silky_terrier
# 127                  Smooth_fox_terrier
# 128                     Tibetan_mastiff
# 129              Welsh_springer_spaniel
# 130         Wirehaired_pointing_griffon
# 131                      Xoloitzcuintli
# 132                   Yorkshire_terrier
#
# [133 rows x 1 columns]>

# %%
characteristics_subset.count
# Out:
# <bound method DataFrame.count of                               BreedName        Group1      Group2  MaleWtKg  \
# 0                         Affenpinscher           Toy   Companion         4
# 1                          Afghan_hound      Sporting       Sight        28
# 2                      Airedale_terrier       Terrier     Terrier        26
# 3                                 Akita       Working     Herding        44
# 4                      Alaskan_malamute       Working    Northern        40
# 5                   American_eskimo_dog  Non Sporting    Northern         8
# 6        American_staffordshire_terrier       Terrier     Terrier        28
# 7                American_water_spaniel      Sporting         Gun        16
# 8                Anatolian_shepherd_dog       Working    Guardian        52
# 9                 Australian_cattle_dog       Herding     Herding        21
# 10                  Australian_shepherd       Terrier     Terrier        27
# 11                   Australian_terrier       Terrier     Terrier         5
# 12                              Basenji         Hound       Sight        11
# 13                         Basset_hound         Hound  Scenthound        26
# 14                               Beagle         Hound  Scenthound        11
# 15                       Bearded_collie       Herding     Herding        23
# 16                            Beauceron       Herding     Herding        50
# 17                   Bedlington_terrier       Terrier     Terrier         9
# 18                     Belgian_sheepdog       Herding     Herding        32
# 19                     Belgian_malinois       Herding     Herding        27
# 20                     Belgian_tervuren       Herding     Herding        34
# 21                 Bernese_mountain_dog       Working    Guardian        44
# 22                         Bichon_frise  Non Sporting   Companion         4
# 23              Black_and_tan_coonhound         Hound  Scenthound        55
# 24                Black_russian_terrier       Working    Guardian        51
# 25                           Bloodhound         Hound  Scenthound        46
# 26                   Bluetick_coonhound         Hound  Scenthound        28
# 27                        Border_collie       Herding     Herding        17
# 28                       Border_terrier       Terrier     Terrier         7
# 29                               Borzoi         Hound       Sight        41
# ..                                  ...           ...         ...       ...
# 103                        Newfoundland       Working    Guardian        65
# 104                     Norfolk_terrier       Terrier     Terrier         5
# 105                    Norwegian_buhund       Herding    Northern        16
# 106                  Norwegian_elkhound         Hound    Northern        26
# 107                 Norwegian_lundehund  Non Sporting    Northern         8
# 108                     Norwich_terrier       Terrier     Terrier         5
# 109  Nova_scotia_duck-tolling_retriever      Sporting    Gun Dogs        20
# 110                Old_english_sheepdog       Herding     Herding        39
# 111                          Otterhound         Hound  Scenthound        41
# 112                            Papillon           Toy   Companion         5
# 113                           Pekingese           Toy   Companion         4
# 114        Petit_basset_griffon_vendeen         Hound  Scenthound        16
# 115                       Pharaoh_hound         Hound       Sight        23
# 116                               Plott         Hound  Scenthound        26
# 117                             Pointer      Sporting         Gun        25
# 118                          Pomeranian           Toy   Companion         2
# 119                              Poodle  Non Sporting         Gun        26
# 120                Portuguese_water_dog       Working         Gun        22
# 121                       Saint_bernard       Working    Guardian        66
# 122                 Miniature_schnauzer       Terrier   Companion         8
# 123                    Chinese_shar-pei  Non Sporting    Northern        22
# 124                       Silky_terrier           Toy     Terrier         5
# 125                  Smooth_fox_terrier       Terrier     Terrier         8
# 126                     Tibetan_mastiff       Working    Guardian        71
# 127                Cardigan_welsh_corgi       Herding     Herding        16
# 128                Pembroke_welsh_corgi       Herding     Herding        12
# 129              Welsh_springer_spaniel      Sporting         Gun        18
# 130         Wirehaired_pointing_griffon      Sporting         Gun        25
# 131                      Xoloitzcuintli  Non Sporting       Sight        11
# 132            Yorkshire_terrier_yorkie           Toy   Companion         3
#
#                                             Temperment  AvgPupPrice  \
# 0    Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1       Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2    Alert, Confident, Courageous, Friendly, Intell...        700.0
# 3    Alert, Courageous, Dignified, Docile, Friendly...       1000.0
# 4    Affectionate, Devoted, Dignified, Friendly, Lo...       1350.0
# 5    Alert, Energetic, Friendly, Independent, Intel...        700.0
# 6    Attentive, Courageous, Devoted, Friendly, Loya...        900.0
# 7    Energetic, Friendly, Intelligent, Obedient, Pr...        900.0
# 8    Bold, Confident, Independent, Intelligent, Pro...        800.0
# 9    Aggressive, Alert, Energetic, Intelligent, Loy...        600.0
# 10   Active, Affectionate, Friendly, Good-natured, ...        700.0
# 11   Alert, Compassionate, Courageous, Even Tempere...       1250.0
# 12   Affectionate, Alert, Curious, Energetic, Playf...       1100.0
# 13   Affectionate, Devoted, Friendly, Gentle, Sweet...        400.0
# 14   Friendly, Gentle, Independent, Intelligent, Li...        650.0
# 15   Active, Alert, Hardy, Intelligent, Lively, Sel...       1300.0
# 16     Courageous, Obedient, Loyal, Protective, Loving       1350.0
# 17   Affectionate, Devoted, Energetic, Loyal, Playf...       1900.0
# 18   Active, Alert, Confident, Friendly, Hard-worki...       1300.0
# 19   Active, Alert, Confident, Friendly, Hard-worki...        700.0
# 20   Alert, Attentive, Energetic, Intelligent, Loya...       1350.0
# 21          Affectionate, Faithful, Intelligent, Loyal        900.0
# 22   Affectionate, Cheerful, Feisty, Gentle, Playfu...        850.0
# 23   Adaptable, Easygoing, Even-tempered, Gentle, L...        350.0
# 24   Brave, Confident, Energetic, Hardy, Lively, St...       2150.0
# 25   Affectionate, Even-tempered, Gentle, Stubborn,...       1000.0
# 26                            Friendly, Active, Gentle        550.0
# 27   Intelligent, Energetic, Alert, Responsive, Ten...        700.0
# 28   Affectionate, Alert, Even-tempered, Fearless, ...       1300.0
# 29   Athletic, Gentle, Independent, Intelligent, Qu...       1100.0
# ..                                                 ...          ...
# 103  Cheerful, Courageous, Intelligent, Loyal, Soci...       1750.0
# 104  Companionable, Fearless, Happy, Lovable, Self-...       2250.0
# 105  Agile, Courageous, Energetic, Friendly, Fun-lo...        900.0
# 106  Alert, Bold, Hardy, Loyal, Playful, Strong-wil...        600.0
# 107                Alert, Energetic, Loyal, Protective        500.0
# 108  Affectionate, Energetic, Hardy, Intelligent, S...       1700.0
# 109  Affectionate, Alert, Courageous, Energetic, Ge...       1900.0
# 110  Adaptable, Bubbly, Intelligent, Loving, Playfu...       1350.0
# 111                 Amiable, Boisterous, Even-tempered        550.0
# 112  Alert, Energetic, Friendly, Happy, Hardy, Inte...        500.0
# 113  Affectionate, Aggressive, Good-natured, Intell...        700.0
# 114  Active, Extroverted, Friendly, Happy, Independ...       1400.0
# 115  Active, Affectionate, Intelligent, Playful, So...       1900.0
# 116                     Alert, Bold, Courageous, Loyal        400.0
# 117  Active, Affectionate, Amiable, Even-tempered, ...        450.0
# 118  Active, Extroverted, Friendly, Intelligent, Li...        700.0
# 119  Active, Alert, Faithful, Instinctual, Intellig...       1250.0
# 120  Brave, Docile, Impetuous, Intelligent, Obedien...       2650.0
# 121  Friendly, Gentle, Independent, Intelligent, Ou...       1650.0
# 122  Devoted, Good-natured, Intelligent, Lively, Pl...        800.0
# 123  Affectionate, Devoted, Independent, Loving, Re...       1100.0
# 124  Alert, Friendly, Inquisitive, Joyful, Quick, R...        700.0
# 125  Active, Affectionate, Alert, Fearless, Intelli...        850.0
# 126  Aloof, Protective, Strong-willed, Stubborn, Co...       3000.0
# 127  Active, Affectionate, Alert, Companionable, De...       1100.0
# 128  Active, Affectionate, Alert, Companionable, De...       1100.0
# 129  Affectionate, Loyal, Active, Friendly, Playful...       1300.0
# 130  Gentle, Loyal, Proud, Trainable, Vigilant, Int...        700.0
# 131  Aleret, Calm, Cheerful, Companionable, Loyal, ...        700.0
# 132  Alert, Courageous, Energetic, Independent, Int...        800.0
#
#      Intelligence  Watchdog  PopularityUS2017
# 0            37.0       1.0             147.0
# 1            79.0       1.0              93.0
# 2            29.0       4.0              55.0
# 3            54.0       5.0              47.0
# 4            50.0       5.0              59.0
# 5             NaN       4.0             118.0
# 6            34.0       3.0              83.0
# 7            44.0       4.0             167.0
# 8             NaN       6.0              86.0
# 9            10.0       6.0              56.0
# 10           42.0       5.0              17.0
# 11           34.0       3.0             137.0
# 12           78.0       5.0              84.0
# 13           71.0       1.0              39.0
# 14           72.0       1.0               6.0
# 15           34.0       4.0             125.0
# 16            NaN       5.0             141.0
# 17           40.0       3.0             151.0
# 18           15.0       6.0             120.0
# 19            NaN       6.0              44.0
# 20           14.0       6.0             103.0
# 21           22.0       5.0              25.0
# 22           45.0       3.0              46.0
# 23           44.0       3.0             130.0
# 24            NaN       6.0             116.0
# 25           74.0       1.0              50.0
# 26            NaN       1.0             132.0
# 27            1.0       6.0              38.0
# 28           30.0       4.0              92.0
# 29           75.0       1.0             102.0
# ..            ...       ...               ...
# 103          34.0       5.0              36.0
# 104          56.0       3.0             128.0
# 105           NaN       4.0             170.0
# 106          36.0       6.0              91.0
# 107           NaN       4.0             190.0
# 108          38.0       3.0             105.0
# 109           NaN       5.0              89.0
# 110          63.0       4.0              70.0
# 111          46.0       2.0             186.0
# 112           8.0       3.0              53.0
# 113          73.0       3.0              88.0
# 114          62.0       3.0             160.0
# 115          37.0       2.0             174.0
# 116           NaN       3.0             166.0
# 117          43.0       4.0             113.0
# 118          23.0       3.0              22.0
# 119           2.0       4.0               7.0
# 120           NaN       4.0              54.0
# 121          65.0       3.0              48.0
# 122           NaN       NaN              18.0
# 123          51.0       3.0              64.0
# 124          37.0       3.0             106.0
# 125          40.0       3.0             122.0
# 126           NaN       6.0             153.0
# 127          26.0       4.0              68.0
# 128          26.0       4.0              68.0
# 129          31.0       4.0             133.0
# 130          46.0       5.0              65.0
# 131           NaN       3.0             143.0
# 132          27.0       3.0               9.0
#
# [133 rows x 9 columns]>

# %%
characteristics_subset.to_csv("Resources/Breed_Characteristics.csv")
