# %%
import pandas as pd

# %%
csv_file1 = "recallDf.csv"
characteristics = pd.read_csv(csv_file1)

# %%
characteristics
# Out:
#                              Breed Name  Precision    Recall  Accuracy  \
# 0                         Affenpinscher   1.000000  0.875000  0.933333
# 1                          Afghan_hound   0.875000  0.875000  0.875000
# 2                      Airedale_terrier   0.857143  1.000000  0.923077
# 3                                 Akita   0.888889  1.000000  0.941176
# 4                      Alaskan_malamute   0.909091  1.000000  0.952381
# 5                   American_eskimo_dog   1.000000  0.875000  0.933333
# 6                     American_foxhound   1.000000  0.857143  0.923077
# 7        American_staffordshire_terrier   1.000000  1.000000  1.000000
# 8                American_water_spaniel   1.000000  0.250000  0.400000
# 9                Anatolian_shepherd_dog   0.750000  1.000000  0.857143
# 10                Australian_cattle_dog   1.000000  0.777778  0.875000
# 11                  Australian_shepherd   1.000000  0.777778  0.875000
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
characteristics
# Out:
#                              Breed Name  Precision  Recall  Accuracy  Support
# 0                         Affenpinscher       1.00    0.88      0.93        8
# 1                          Afghan_hound       0.88    0.88      0.88        8
# 2                      Airedale_terrier       0.86    1.00      0.92        6
# 3                                 Akita       0.89    1.00      0.94        8
# 4                      Alaskan_malamute       0.91    1.00      0.95       10
# 5                   American_eskimo_dog       1.00    0.88      0.93        8
# 6                     American_foxhound       1.00    0.86      0.92        7
# 7        American_staffordshire_terrier       1.00    1.00      1.00        8
# 8                American_water_spaniel       1.00    0.25      0.40        4
# 9                Anatolian_shepherd_dog       0.75    1.00      0.86        6
# 10                Australian_cattle_dog       1.00    0.78      0.88        9
# ...

# %%
html = characteristics.to_html()

# %%
text_file = open("data.html", "w")
text_file.write(html)
text_file.close()
